# %%
from CC.trainer import NERTrainer
os.environ['CUDA_VISIBLE_DEVICES']='1'
args = {
    'num_epochs': 30,
    'num_gpus': [0],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    'hidden_dim': 300,
    'max_seq_length': 20,
    'max_scan_num': 1000000,
    'train_file': './data/ccks/before/subtask1_train.json',
    'eval_file': './data/ccks/subtask1_test.json',
    'test_file': './data/ccks/subtask1_test.json',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': 'data/ccks/ccks_tags_list.txt',
    'loader_name': 'le_loader',
    'output_eval':True,
    "word_embedding_file":"./data/tencent/word_embedding.txt",
    "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "default_tag":"O",
    'batch_size': 8,
    'eval_batch_size': 64,
    'do_shuffle': True,
    "use_gpu": True,
    "debug": True,
    'model_name': 'LEBert',
    'classify':'crf',
    'task_name': 'ccks_LEBert_seq_20_1'
}


# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_LEBert_seq_20_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_LEBert_seq_20_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_LEBert_seq_20_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_LEBert_seq_20_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i

args['max_seq_length'] = 140
args["task_name"] = "ccks_LEBert_seq_140_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_140_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_140_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_140_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_140_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args['max_seq_length'] = 160
args["task_name"] = "ccks_LEBert_seq_160_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_160_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_160_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_160_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_160_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i

args['max_seq_length'] = 180
args["task_name"] = "ccks_LEBert_seq_180_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_180_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_180_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_180_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_180_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args['max_seq_length'] = 200
args["task_name"] = "ccks_LEBert_seq_200_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_200_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_200_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_200_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_200_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i

# %%
from CC.trainer import NERTrainer
os.environ['CUDA_VISIBLE_DEVICES']='1'
args = {
    'num_epochs': 30,
    'num_gpus': [0],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    'hidden_dim': 300,
    'max_seq_length': 20,
    'max_scan_num': 1000000,
    'train_file': './data/ccks/before/subtask1_train.json',
    'eval_file': './data/ccks/subtask1_test.json',
    'test_file': './data/ccks/subtask1_test.json',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': 'data/ccks/ccks_tags_list.txt',
    'loader_name': 'le_loader',
    'output_eval':True,
    "word_embedding_file":"./data/tencent/word_embedding.txt",
    "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "default_tag":"O",
    'batch_size': 8,
    'eval_batch_size': 64,
    'do_shuffle': True,
    "use_gpu": True,
    "debug": True,
    'model_name': 'LEBert',
    'classify':'crf',
    'task_name': 'ccks_LEBert_seq_20_1'
}


args['max_seq_length'] = 220
args["task_name"] = "ccks_LEBert_seq_220_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_220_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_220_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_220_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_220_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i

args['max_seq_length'] = 250
args["task_name"] = "ccks_LEBert_seq_250_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_250_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_250_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_250_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_LEBert_seq_250_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i

# %%
# os.environ['CUDA_VISIBLE_DEVICES']='1'
from CC.trainer import NERTrainer

args = {
    'num_epochs': 30,
    'num_gpus': [0],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    'hidden_dim': 150,
    'max_seq_length': 20,
    'train_file': './data/ccks/conll/train_1000.txt',
    'eval_file': './data/ccks/conll/subtask1_test_set_with_answer.txt',
    'test_file': './data/ccks/conll/subtask1_test_set_with_answer.txt',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': 'data/ccks/ccks_tags_list.txt',
    'loader_name': 'cn_loader',
    'output_eval':True,
    "default_tag":"O",
    'batch_size': 8,
    'eval_batch_size': 64,
    'do_shuffle': True,
    "use_gpu": True,
    "debug": True,
    'model_name': 'Bert',
    'classify':'lstm_crf',
    'task_name': 'ccks_bert_seq_20_1',

}

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i
args['max_seq_length'] = 120
args["task_name"] = "ccks_bert_seq_120_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_120_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_120_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_120_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_120_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i

# %%
# os.environ['CUDA_VISIBLE_DEVICES']='1'
from CC.trainer import NERTrainer

args = {
    'num_epochs': 30,
    'num_gpus': [0],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    'hidden_dim': 150,
    'max_seq_length': 20,
    'train_file': './data/ccks/conll/train_1000.txt',
    'eval_file': './data/ccks/conll/subtask1_test_set_with_answer.txt',
    'test_file': './data/ccks/conll/subtask1_test_set_with_answer.txt',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': 'data/ccks/ccks_tags_list.txt',
    'loader_name': 'cn_loader',
    'output_eval':True,
    "default_tag":"O",
    'batch_size': 8,
    'eval_batch_size': 64,
    'do_shuffle': True,
    "use_gpu": True,
    "debug": True,
    'model_name': 'Bert',
    'classify':'lstm_crf',
    'task_name': 'ccks_bert_seq_20_1',

}

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i
args['max_seq_length'] = 100
args["task_name"] = "ccks_bert_seq_100_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_100_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_100_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_100_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_bert_seq_100_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i
