# %%
from CC.trainer import NERTrainer

args = {
    'num_epochs': 30,
    'num_gpus': [0],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    # 'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    'pretrained_file_name': './save_pretrained/ccks_pre_4/Bert_19215/pytorch_model.bin',
    'hidden_dim': 300,
    'max_seq_length': 20,
    'max_scan_num': 1000000,
    'inter_max_scan_num': 20000,
    'train_file': './data/ccks/before/subtask1_train.json',
    'eval_file': './data/ccks/subtask1_test.json',
    'test_file': './data/ccks/subtask1_test.json',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': 'data/ccks/ccks_tags_list.txt',
    'loader_name': 'le_loader_zl',
    'output_eval':True,
    "word_embedding_file":"./data/tencent/word_embedding.txt",
    "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "inter_knowledge_file":"./data/tencent/THUOCL_FN_medical.txt",
    "default_tag":"O",
    'batch_size': 8,
    'eval_batch_size': 64,
    'do_shuffle': True,
    "use_gpu": True,
    "debug": True,
    'model_name': 'ZLEBert',
    'classify':'lstm_crf',
    'task_name': 'ccks_v1_seq_pro_4_20_1'
}

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_20_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_20_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_20_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_20_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


args['max_seq_length'] = 40
args["task_name"] = "ccks_v1_seq_pro_4_40_1"
trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_seq_pro_4_40_2"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_seq_pro_4_40_3"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_seq_pro_4_40_4"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i


args["task_name"] = "ccks_v1_seq_pro_4_40_5"

trainer = NERTrainer(**args)

for i in trainer(lr2=1e-2):
    a = i



# args['max_seq_length'] = 60
# args["task_name"] = "ccks_v1_seq_pro_4_60_1"
# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_60_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_60_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_60_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_60_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i



# args['max_seq_length'] = 80
# args["task_name"] = "ccks_v1_seq_pro_4_80_1"
# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_80_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_80_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_80_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_80_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i

# args['max_seq_length'] = 100
# args["task_name"] = "ccks_v1_seq_pro_4_100_1"
# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_100_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_100_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_100_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_100_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args['max_seq_length'] = 120
# args["task_name"] = "ccks_v1_seq_pro_4_120_1"
# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_120_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_120_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_120_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_120_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args['max_seq_length'] = 140
# args["task_name"] = "ccks_v1_seq_pro_4_140_1"
# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_140_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_140_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_140_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_140_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i



# args['max_seq_length'] = 160
# args["task_name"] = "ccks_v1_seq_pro_4_160_1"
# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_160_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_160_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_160_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_160_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i

# args['max_seq_length'] = 180
# args["task_name"] = "ccks_v1_seq_pro_4_180_1"
# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_180_2"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_180_3"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_180_4"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i


# args["task_name"] = "ccks_v1_seq_pro_4_180_5"

# trainer = NERTrainer(**args)

# for i in trainer(lr2=1e-2):
#     a = i
