# %% [markdown]
# ## FN

# %% [markdown]
# ## 四川上训练测试验证

# %%
# %%
import json
from CC.predicter import NERPredict
from CC.trainer import NERTrainer
#os.environ['CUDA_VISIBLE_DEVICES']='2,3'

# %%
args = {
    'num_epochs': 30,
    'num_gpus': [0, 1],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained/Bert_95250/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained_3/Bert_95250/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained_4/Bert_95250/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained_5/Bert_95250/pytorch_model.bin',
    'hidden_dim': 300,
    # 'max_scan_num': 1000000,
    'train_file': './data/FN/fj+sc/train(2w+240).csv',
    'eval_file': './data/FN/fj/dev.csv',
    'test_file': './data/FN/fj/test.csv',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': './data/FN/tags_list.txt',
    'output_eval': True,
    'loader_name': 'cn_loader',
    # "word_embedding_file":"./data/tencent/word_embedding.txt",
    # "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "default_tag":"O",
    'batch_size': 64,
    'eval_batch_size': 64,
    'do_shuffle': True,
    # 'pattern': ',	O', 
    'model_name': 'Bert',
    'task_name': 'FN-fj+sc(2w+240)-fj'
}
trainer = NERTrainer(**args)

for i in trainer():
    a = i
# Out:
# Some weights of the model checkpoint at ./model/chinese_wwm_ext/pytorch_model.bin were not used when initializing BertBaseModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertBaseModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertBaseModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertBaseModel were not initialized from the model checkpoint at ./model/chinese_wwm_ext/pytorch_model.bin and are newly initialized: ['bert.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: 1/30 Train: 100%|██████████| 334/334 [02:22<00:00,  2.35it/s, F1=0.532, train_acc=0.908, train_loss=13.3, train_precision=0.464, train_recall=0.633]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.51it/s, F1=0.808, eval_acc=0.985, eval_loss=2.47, eval_precision=0.721, eval_recall=0.925]
# Epoch: 2/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.794, train_acc=0.986, train_loss=2.28, train_precision=0.711, train_recall=0.907]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.80it/s, F1=0.851, eval_acc=0.988, eval_loss=2.14, eval_precision=0.78, eval_recall=0.943]
# Epoch: 3/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.844, train_acc=0.989, train_loss=1.82, train_precision=0.776, train_recall=0.93]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.63it/s, F1=0.871, eval_acc=0.989, eval_loss=1.97, eval_precision=0.807, eval_recall=0.95]
# Epoch: 4/30 Train: 100%|██████████| 334/334 [02:22<00:00,  2.35it/s, F1=0.876, train_acc=0.99, train_loss=1.56, train_precision=0.822, train_recall=0.94]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.60it/s, F1=0.892, eval_acc=0.989, eval_loss=1.84, eval_precision=0.844, eval_recall=0.95]
# Epoch: 5/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.35it/s, F1=0.901, train_acc=0.991, train_loss=1.31, train_precision=0.858, train_recall=0.95]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.84it/s, F1=0.904, eval_acc=0.989, eval_loss=1.84, eval_precision=0.862, eval_recall=0.953]
# Epoch: 6/30 Train: 100%|██████████| 334/334 [02:23<00:00,  2.32it/s, F1=0.924, train_acc=0.993, train_loss=1.09, train_precision=0.894, train_recall=0.957]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.40it/s, F1=0.916, eval_acc=0.989, eval_loss=1.85, eval_precision=0.884, eval_recall=0.952]
# Epoch: 7/30 Train: 100%|██████████| 334/334 [02:24<00:00,  2.32it/s, F1=0.94, train_acc=0.993, train_loss=0.979, train_precision=0.917, train_recall=0.964]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.58it/s, F1=0.929, eval_acc=0.99, eval_loss=1.59, eval_precision=0.899, eval_recall=0.962]
# Epoch: 8/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.947, train_acc=0.994, train_loss=0.883, train_precision=0.928, train_recall=0.967]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.77it/s, F1=0.927, eval_acc=0.989, eval_loss=1.6, eval_precision=0.9, eval_recall=0.956]
# Epoch: 9/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.954, train_acc=0.994, train_loss=0.752, train_precision=0.935, train_recall=0.973]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.65it/s, F1=0.93, eval_acc=0.989, eval_loss=1.39, eval_precision=0.902, eval_recall=0.96]
# Epoch: 10/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.956, train_acc=0.995, train_loss=0.667, train_precision=0.939, train_recall=0.974]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.58it/s, F1=0.934, eval_acc=0.989, eval_loss=1.46, eval_precision=0.909, eval_recall=0.962]
# Epoch: 11/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.959, train_acc=0.995, train_loss=0.594, train_precision=0.943, train_recall=0.976]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.80it/s, F1=0.93, eval_acc=0.989, eval_loss=1.47, eval_precision=0.899, eval_recall=0.966]
# Epoch: 12/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.96, train_acc=0.995, train_loss=0.532, train_precision=0.945, train_recall=0.977]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.61it/s, F1=0.939, eval_acc=0.99, eval_loss=1.48, eval_precision=0.913, eval_recall=0.968]
# Epoch: 13/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.966, train_acc=0.996, train_loss=0.466, train_precision=0.951, train_recall=0.981]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.68it/s, F1=0.929, eval_acc=0.988, eval_loss=1.31, eval_precision=0.902, eval_recall=0.958]
# Epoch: 14/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.966, train_acc=0.996, train_loss=0.41, train_precision=0.952, train_recall=0.981]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.81it/s, F1=0.936, eval_acc=0.99, eval_loss=1.28, eval_precision=0.913, eval_recall=0.962]
# Epoch: 15/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.969, train_acc=0.996, train_loss=0.344, train_precision=0.955, train_recall=0.983]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.68it/s, F1=0.935, eval_acc=0.99, eval_loss=1.4, eval_precision=0.912, eval_recall=0.961]
# Epoch: 16/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.97, train_acc=0.996, train_loss=0.319, train_precision=0.956, train_recall=0.984]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.55it/s, F1=0.937, eval_acc=0.99, eval_loss=1.37, eval_precision=0.911, eval_recall=0.966]
# Epoch: 17/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.971, train_acc=0.996, train_loss=0.296, train_precision=0.957, train_recall=0.985]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.79it/s, F1=0.933, eval_acc=0.989, eval_loss=1.13, eval_precision=0.906, eval_recall=0.964]
# Epoch: 18/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.971, train_acc=0.997, train_loss=0.264, train_precision=0.958, train_recall=0.986]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.65it/s, F1=0.934, eval_acc=0.989, eval_loss=1.39, eval_precision=0.911, eval_recall=0.959]
# Epoch: 19/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.973, train_acc=0.997, train_loss=0.255, train_precision=0.96, train_recall=0.987]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.63it/s, F1=0.937, eval_acc=0.989, eval_loss=1.15, eval_precision=0.912, eval_recall=0.965]
# Epoch: 20/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.973, train_acc=0.997, train_loss=0.231, train_precision=0.96, train_recall=0.987]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.78it/s, F1=0.929, eval_acc=0.988, eval_loss=1.05, eval_precision=0.916, eval_recall=0.945]
# Epoch: 21/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.35it/s, F1=0.974, train_acc=0.997, train_loss=0.21, train_precision=0.961, train_recall=0.987]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.58it/s, F1=0.936, eval_acc=0.989, eval_loss=0.98, eval_precision=0.917, eval_recall=0.957]
# Epoch: 22/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.35it/s, F1=0.975, train_acc=0.997, train_loss=0.193, train_precision=0.962, train_recall=0.989]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.65it/s, F1=0.931, eval_acc=0.989, eval_loss=1.28, eval_precision=0.914, eval_recall=0.951]
# Epoch: 23/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.977, train_acc=0.997, train_loss=0.166, train_precision=0.965, train_recall=0.99]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.75it/s, F1=0.933, eval_acc=0.989, eval_loss=1.2, eval_precision=0.912, eval_recall=0.956]
# Epoch: 24/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.977, train_acc=0.997, train_loss=0.165, train_precision=0.965, train_recall=0.99]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.60it/s, F1=0.933, eval_acc=0.989, eval_loss=1.27, eval_precision=0.922, eval_recall=0.947]
# Epoch: 25/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.35it/s, F1=0.979, train_acc=0.997, train_loss=0.144, train_precision=0.966, train_recall=0.992]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.65it/s, F1=0.934, eval_acc=0.989, eval_loss=1.35, eval_precision=0.917, eval_recall=0.954]
# Epoch: 26/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.977, train_acc=0.997, train_loss=0.15, train_precision=0.964, train_recall=0.99]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.84it/s, F1=0.934, eval_acc=0.989, eval_loss=1.1, eval_precision=0.914, eval_recall=0.956]
# Epoch: 27/30 Train: 100%|██████████| 334/334 [02:22<00:00,  2.35it/s, F1=0.978, train_acc=0.997, train_loss=0.143, train_precision=0.966, train_recall=0.99]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.66it/s, F1=0.931, eval_acc=0.988, eval_loss=1.17, eval_precision=0.91, eval_recall=0.955]
# Epoch: 28/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.979, train_acc=0.997, train_loss=0.129, train_precision=0.967, train_recall=0.992]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.59it/s, F1=0.935, eval_acc=0.989, eval_loss=1.18, eval_precision=0.913, eval_recall=0.96]
# Epoch: 29/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.978, train_acc=0.997, train_loss=0.13, train_precision=0.967, train_recall=0.991]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.79it/s, F1=0.933, eval_acc=0.989, eval_loss=1.01, eval_precision=0.915, eval_recall=0.952]
# Epoch: 30/30 Train: 100%|██████████| 334/334 [02:21<00:00,  2.36it/s, F1=0.978, train_acc=0.997, train_loss=0.123, train_precision=0.967, train_recall=0.991]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.68it/s, F1=0.936, eval_acc=0.989, eval_loss=0.942, eval_precision=0.915, eval_recall=0.961]

# %% [markdown]
# ## 四川+福建上训练，在四川数据集上验证

# %%
args = {
    'num_epochs': 30,
    'num_gpus': [0, 1],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained/Bert_95250/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained_3/Bert_95250/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained_4/Bert_95250/pytorch_model.bin',
    'hidden_dim': 300,
    # 'max_scan_num': 1000000,
    'train_file': './data/FN/fj+sc/train.csv',
    'eval_file': './data/FN/sc/dev.csv',
    'test_file': './data/FN/sc/test.csv',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': './data/FN/tags_list.txt',
    'output_eval': True,
    'loader_name': 'cn_loader',
    # "word_embedding_file":"./data/tencent/word_embedding.txt",
    # "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "default_tag":"O",
    'batch_size': 64,
    'eval_batch_size': 64,
    'do_shuffle': True,
    # 'pattern': ',	O', 
    'model_name': 'Bert',
    'task_name': 'FN-sc+fj_test-sc'
}

trainer = NERTrainer(**args)

for i in trainer():
    a = i
# Out:
# Some weights of the model checkpoint at ./model/chinese_wwm_ext/pytorch_model.bin were not used when initializing BertBaseModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertBaseModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertBaseModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertBaseModel were not initialized from the model checkpoint at ./model/chinese_wwm_ext/pytorch_model.bin and are newly initialized: ['bert.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: 1/30 Train:   9%|▉         | 30/332 [00:14<02:08,  2.35it/s, F1=9.27e-5, train_acc=0.522, train_loss=80.9, train_precision=4.8e-5, train_recall=0.00135]/home/zl/miniconda3/envs/FN/lib/python3.8/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 1/30 Train: 100%|██████████| 332/332 [02:23<00:00,  2.31it/s, F1=0.484, train_acc=0.924, train_loss=15.3, train_precision=0.409, train_recall=0.6]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  9.29it/s, F1=0, eval_acc=0.981, eval_loss=4.93, eval_precision=0, eval_recall=0]
# Epoch: 2/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.759, train_acc=0.986, train_loss=3.29, train_precision=0.666, train_recall=0.893]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  8.51it/s, F1=0, eval_acc=0.993, eval_loss=1.13, eval_precision=0, eval_recall=0]
# Epoch: 3/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.811, train_acc=0.988, train_loss=2.62, train_precision=0.731, train_recall=0.92]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  8.56it/s, F1=0, eval_acc=0.999, eval_loss=0.289, eval_precision=0, eval_recall=0]
# Epoch: 4/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.843, train_acc=0.99, train_loss=2.18, train_precision=0.773, train_recall=0.933]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.85it/s, F1=0, eval_acc=0.997, eval_loss=0.449, eval_precision=0, eval_recall=0]
# Epoch: 5/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.86, train_acc=0.991, train_loss=1.89, train_precision=0.796, train_recall=0.94]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.49it/s, F1=0, eval_acc=0.993, eval_loss=2.06, eval_precision=0, eval_recall=0]
# Epoch: 6/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.883, train_acc=0.992, train_loss=1.64, train_precision=0.828, train_recall=0.949]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.98it/s, F1=0, eval_acc=0.997, eval_loss=0.472, eval_precision=0, eval_recall=0]
# Epoch: 7/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.898, train_acc=0.993, train_loss=1.43, train_precision=0.85, train_recall=0.955]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.58it/s, F1=0, eval_acc=0.997, eval_loss=0.324, eval_precision=0, eval_recall=0]
# Epoch: 8/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.918, train_acc=0.994, train_loss=1.23, train_precision=0.878, train_recall=0.963]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.34it/s, F1=0, eval_acc=0.994, eval_loss=0.466, eval_precision=0, eval_recall=0]
# Epoch: 9/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.923, train_acc=0.994, train_loss=1.11, train_precision=0.886, train_recall=0.965]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.58it/s, F1=0.667, eval_acc=0.999, eval_loss=0.273, eval_precision=0.5, eval_recall=1]
# Epoch: 10/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.931, train_acc=0.995, train_loss=0.943, train_precision=0.898, train_recall=0.969]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.80it/s, F1=0, eval_acc=0.996, eval_loss=0.729, eval_precision=0, eval_recall=0]
# Epoch: 11/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.942, train_acc=0.995, train_loss=0.824, train_precision=0.915, train_recall=0.973]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  8.56it/s, F1=0, eval_acc=0.996, eval_loss=0.465, eval_precision=0, eval_recall=0]
# Epoch: 12/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.95, train_acc=0.995, train_loss=0.743, train_precision=0.926, train_recall=0.976]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.89it/s, F1=0, eval_acc=0.996, eval_loss=0.673, eval_precision=0, eval_recall=0]
# Epoch: 13/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.958, train_acc=0.996, train_loss=0.623, train_precision=0.939, train_recall=0.978]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  8.21it/s, F1=0, eval_acc=0.996, eval_loss=0.683, eval_precision=0, eval_recall=0]
# Epoch: 14/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.964, train_acc=0.996, train_loss=0.533, train_precision=0.946, train_recall=0.983]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.49it/s, F1=0, eval_acc=0.996, eval_loss=0.337, eval_precision=0, eval_recall=0]
# Epoch: 15/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.965, train_acc=0.996, train_loss=0.474, train_precision=0.95, train_recall=0.982]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  7.95it/s, F1=0, eval_acc=0.996, eval_loss=0.33, eval_precision=0, eval_recall=0]
# Epoch: 16/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.968, train_acc=0.996, train_loss=0.416, train_precision=0.953, train_recall=0.983]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.52it/s, F1=0, eval_acc=0.996, eval_loss=0.411, eval_precision=0, eval_recall=0]
# Epoch: 17/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.969, train_acc=0.996, train_loss=0.376, train_precision=0.955, train_recall=0.985]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.85it/s, F1=1, eval_acc=1, eval_loss=0.0964, eval_precision=1, eval_recall=1]
# Epoch: 18/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.971, train_acc=0.997, train_loss=0.318, train_precision=0.957, train_recall=0.987]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.85it/s, F1=1, eval_acc=1, eval_loss=0.07, eval_precision=1, eval_recall=1]
# Epoch: 19/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.973, train_acc=0.997, train_loss=0.275, train_precision=0.959, train_recall=0.988]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.89it/s, F1=0, eval_acc=0.996, eval_loss=0.161, eval_precision=0, eval_recall=0]
# Epoch: 20/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.973, train_acc=0.997, train_loss=0.256, train_precision=0.96, train_recall=0.988]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.80it/s, F1=0, eval_acc=0.996, eval_loss=0.202, eval_precision=0, eval_recall=0]
# Epoch: 21/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.975, train_acc=0.997, train_loss=0.237, train_precision=0.961, train_recall=0.989]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.35it/s, F1=0, eval_acc=0.996, eval_loss=0.115, eval_precision=0, eval_recall=0]
# Epoch: 22/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.975, train_acc=0.997, train_loss=0.218, train_precision=0.961, train_recall=0.989]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.66it/s, F1=1, eval_acc=1, eval_loss=0.0526, eval_precision=1, eval_recall=1]
# Epoch: 23/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.977, train_acc=0.997, train_loss=0.183, train_precision=0.963, train_recall=0.991]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.92it/s, F1=1, eval_acc=1, eval_loss=0.0373, eval_precision=1, eval_recall=1]
# Epoch: 24/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.34it/s, F1=0.976, train_acc=0.997, train_loss=0.196, train_precision=0.963, train_recall=0.989]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  8.98it/s, F1=0, eval_acc=0.996, eval_loss=0.405, eval_precision=0, eval_recall=0]
# Epoch: 25/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.978, train_acc=0.997, train_loss=0.175, train_precision=0.965, train_recall=0.991]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.20it/s, F1=0, eval_acc=0.996, eval_loss=0.359, eval_precision=0, eval_recall=0]
# Epoch: 26/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.979, train_acc=0.998, train_loss=0.151, train_precision=0.967, train_recall=0.992]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  8.58it/s, F1=1, eval_acc=1, eval_loss=0.0107, eval_precision=1, eval_recall=1]
# Epoch: 27/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.98, train_acc=0.998, train_loss=0.137, train_precision=0.967, train_recall=0.993]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00, 10.27it/s, F1=0, eval_acc=0.996, eval_loss=0.0852, eval_precision=0, eval_recall=0]
# Epoch: 28/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.98, train_acc=0.998, train_loss=0.136, train_precision=0.967, train_recall=0.993]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  7.97it/s, F1=0, eval_acc=0.996, eval_loss=0.151, eval_precision=0, eval_recall=0]
# Epoch: 29/30 Train: 100%|██████████| 332/332 [02:22<00:00,  2.33it/s, F1=0.978, train_acc=0.997, train_loss=0.143, train_precision=0.965, train_recall=0.991]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  8.19it/s, F1=1, eval_acc=1, eval_loss=0.0605, eval_precision=1, eval_recall=1]
# Epoch: 30/30 Train: 100%|██████████| 332/332 [02:21<00:00,  2.34it/s, F1=0.978, train_acc=0.997, train_loss=0.142, train_precision=0.966, train_recall=0.991]
# Eval Result: 100%|██████████| 1/1 [00:00<00:00,  9.04it/s, F1=0, eval_acc=0.996, eval_loss=0.0854, eval_precision=0, eval_recall=0]

# %% [markdown]
# ## 预训练pretrain—file训练FJ数据集

# %%
args = {
    'num_epochs': 30,
    'num_gpus': [0, 1],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    # 'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    # 'pretrained_file_name': './save_pretrained/FN_Pretrained/Bert_95250/pytorch_model.bin',
    'pretrained_file_name': './save_pretrained/FN_Pretrained_5/Bert_95250/pytorch_model.bin',
    'hidden_dim': 300,
    # 'max_scan_num': 1000000,
    'train_file': './data/FN/fj/train.csv',
    'eval_file': './data/FN/fj/dev.csv',
    'test_file': './data/FN/fj/test.csv',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': './data/FN/tags_list.txt',
    'output_eval': True,
    'loader_name': 'cn_loader',
    # "word_embedding_file":"./data/tencent/word_embedding.txt",
    # "word_vocab_file":"./data/tencent/tencent_vocab.txt",
    "default_tag":"O",
    'batch_size': 64,
    'eval_batch_size': 64,
    'do_shuffle': True,
    'model_name': 'Bert',
    'task_name': 'FN-train-FJ_5'
}

trainer = NERTrainer(**args)

for i in trainer():
    a = i

# %%
# 我的prompt：
# 北京和福州都是一座城市，北京是一个地名，福州是一个地名

# 北京和福州都是一座城市，北京是一个地名
# 北京和福州都是一座城市，福州是一个地名
# Out:
# Some weights of the model checkpoint at ./save_pretrained/FN_Pretrained_5/Bert_95250/pytorch_model.bin were not used when initializing BertBaseModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertBaseModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertBaseModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertBaseModel were not initialized from the model checkpoint at ./save_pretrained/FN_Pretrained_5/Bert_95250/pytorch_model.bin and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: 1/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.31it/s, F1=0.493, train_acc=0.901, train_loss=10.7, train_precision=0.467, train_recall=0.525]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.74it/s, F1=0.853, eval_acc=0.986, eval_loss=1.85, eval_precision=0.809, eval_recall=0.904]
# Epoch: 2/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.31it/s, F1=0.878, train_acc=0.987, train_loss=1.71, train_precision=0.844, train_recall=0.917]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.70it/s, F1=0.906, eval_acc=0.988, eval_loss=1.43, eval_precision=0.867, eval_recall=0.952]
# Epoch: 3/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.909, train_acc=0.99, train_loss=1.3, train_precision=0.881, train_recall=0.94]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.55it/s, F1=0.918, eval_acc=0.989, eval_loss=1.3, eval_precision=0.885, eval_recall=0.956]
# Epoch: 4/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.927, train_acc=0.992, train_loss=1.06, train_precision=0.903, train_recall=0.953]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.49it/s, F1=0.917, eval_acc=0.989, eval_loss=1.24, eval_precision=0.887, eval_recall=0.952]
# Epoch: 5/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.935, train_acc=0.993, train_loss=0.912, train_precision=0.912, train_recall=0.959]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.63it/s, F1=0.922, eval_acc=0.989, eval_loss=1.16, eval_precision=0.891, eval_recall=0.957]
# Epoch: 6/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.944, train_acc=0.994, train_loss=0.788, train_precision=0.923, train_recall=0.966]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.50it/s, F1=0.922, eval_acc=0.989, eval_loss=1.14, eval_precision=0.898, eval_recall=0.949]
# Epoch: 7/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.953, train_acc=0.995, train_loss=0.634, train_precision=0.933, train_recall=0.973]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.52it/s, F1=0.921, eval_acc=0.989, eval_loss=1.17, eval_precision=0.897, eval_recall=0.948]
# Epoch: 8/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.956, train_acc=0.995, train_loss=0.569, train_precision=0.938, train_recall=0.976]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.74it/s, F1=0.921, eval_acc=0.988, eval_loss=1.13, eval_precision=0.893, eval_recall=0.953]
# Epoch: 9/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.962, train_acc=0.996, train_loss=0.476, train_precision=0.945, train_recall=0.981]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.55it/s, F1=0.92, eval_acc=0.989, eval_loss=1.15, eval_precision=0.892, eval_recall=0.952]
# Epoch: 10/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.965, train_acc=0.996, train_loss=0.426, train_precision=0.949, train_recall=0.983]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.56it/s, F1=0.923, eval_acc=0.989, eval_loss=1.13, eval_precision=0.895, eval_recall=0.954]
# Epoch: 11/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.967, train_acc=0.997, train_loss=0.385, train_precision=0.951, train_recall=0.984]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.66it/s, F1=0.923, eval_acc=0.989, eval_loss=1.09, eval_precision=0.898, eval_recall=0.952]
# Epoch: 12/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.971, train_acc=0.997, train_loss=0.338, train_precision=0.956, train_recall=0.987]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.59it/s, F1=0.925, eval_acc=0.989, eval_loss=1.11, eval_precision=0.897, eval_recall=0.957]
# Epoch: 13/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.973, train_acc=0.997, train_loss=0.298, train_precision=0.959, train_recall=0.989]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.60it/s, F1=0.924, eval_acc=0.989, eval_loss=1.07, eval_precision=0.9, eval_recall=0.952]
# Epoch: 14/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.974, train_acc=0.997, train_loss=0.279, train_precision=0.96, train_recall=0.989]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.71it/s, F1=0.926, eval_acc=0.989, eval_loss=1.12, eval_precision=0.896, eval_recall=0.96]
# Epoch: 15/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.976, train_acc=0.997, train_loss=0.252, train_precision=0.961, train_recall=0.991]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.53it/s, F1=0.927, eval_acc=0.989, eval_loss=1.05, eval_precision=0.895, eval_recall=0.963]
# Epoch: 16/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.978, train_acc=0.998, train_loss=0.226, train_precision=0.964, train_recall=0.992]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.51it/s, F1=0.923, eval_acc=0.988, eval_loss=1.1, eval_precision=0.9, eval_recall=0.948]
# Epoch: 17/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.977, train_acc=0.997, train_loss=0.224, train_precision=0.963, train_recall=0.991]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.70it/s, F1=0.924, eval_acc=0.989, eval_loss=1.03, eval_precision=0.9, eval_recall=0.949]
# Epoch: 18/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.978, train_acc=0.998, train_loss=0.212, train_precision=0.964, train_recall=0.993]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.54it/s, F1=0.929, eval_acc=0.989, eval_loss=0.976, eval_precision=0.909, eval_recall=0.952]
# Epoch: 19/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.98, train_acc=0.998, train_loss=0.176, train_precision=0.967, train_recall=0.994]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.57it/s, F1=0.928, eval_acc=0.989, eval_loss=0.985, eval_precision=0.904, eval_recall=0.954]
# Epoch: 20/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.981, train_acc=0.998, train_loss=0.17, train_precision=0.968, train_recall=0.995]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.63it/s, F1=0.925, eval_acc=0.988, eval_loss=1.02, eval_precision=0.897, eval_recall=0.956]
# Epoch: 21/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.981, train_acc=0.998, train_loss=0.153, train_precision=0.968, train_recall=0.995]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.58it/s, F1=0.929, eval_acc=0.989, eval_loss=0.976, eval_precision=0.906, eval_recall=0.956]
# Epoch: 22/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.982, train_acc=0.998, train_loss=0.141, train_precision=0.97, train_recall=0.996]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.54it/s, F1=0.93, eval_acc=0.989, eval_loss=1, eval_precision=0.903, eval_recall=0.961]
# Epoch: 23/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.983, train_acc=0.998, train_loss=0.139, train_precision=0.97, train_recall=0.996]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.78it/s, F1=0.926, eval_acc=0.988, eval_loss=1.03, eval_precision=0.908, eval_recall=0.946]
# Epoch: 24/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.982, train_acc=0.998, train_loss=0.147, train_precision=0.969, train_recall=0.995]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.55it/s, F1=0.925, eval_acc=0.989, eval_loss=0.935, eval_precision=0.899, eval_recall=0.955]
# Epoch: 25/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.983, train_acc=0.998, train_loss=0.125, train_precision=0.971, train_recall=0.996]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.60it/s, F1=0.926, eval_acc=0.989, eval_loss=0.948, eval_precision=0.903, eval_recall=0.951]
# Epoch: 26/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.983, train_acc=0.998, train_loss=0.129, train_precision=0.97, train_recall=0.996]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.69it/s, F1=0.926, eval_acc=0.988, eval_loss=0.903, eval_precision=0.905, eval_recall=0.949]
# Epoch: 27/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.983, train_acc=0.998, train_loss=0.122, train_precision=0.97, train_recall=0.996]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.63it/s, F1=0.928, eval_acc=0.988, eval_loss=0.912, eval_precision=0.911, eval_recall=0.946]
# Epoch: 28/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.983, train_acc=0.998, train_loss=0.122, train_precision=0.971, train_recall=0.997]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.54it/s, F1=0.931, eval_acc=0.989, eval_loss=0.942, eval_precision=0.906, eval_recall=0.959]
# Epoch: 29/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.31it/s, F1=0.983, train_acc=0.998, train_loss=0.118, train_precision=0.97, train_recall=0.996]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.72it/s, F1=0.93, eval_acc=0.988, eval_loss=0.838, eval_precision=0.914, eval_recall=0.949]
# Epoch: 30/30 Train: 100%|██████████| 330/330 [02:22<00:00,  2.32it/s, F1=0.984, train_acc=0.998, train_loss=0.113, train_precision=0.971, train_recall=0.997]
# Eval Result: 100%|██████████| 42/42 [00:07<00:00,  5.62it/s, F1=0.93, eval_acc=0.988, eval_loss=0.865, eval_precision=0.906, eval_recall=0.956]

# %% [markdown]
# ## 预训练

# %%
from CC.loaders import *
import pickle
from tqdm import *
from CC.loaders.utils import *
import json
from CC.pre_trained import NERPreTrainer

# %%
# %%
args = {
    'num_epochs': 30,
    'num_gpus': [0, 1, 2],
    'bert_config_file_name': './model/chinese_wwm_ext/bert_config.json',
    'pretrained_file_name': './model/chinese_wwm_ext/pytorch_model.bin',
    'max_seq_length': 512,
    # 'max_scan_num': 1000000,
    'train_file': './data/FN/pre_train.csv',
    # 'eval_file': './data/weibo_L/dev.json',
    # 'test_file': './data/weibo_L/test.json',
    'bert_vocab_file': './model/chinese_wwm_ext/vocab.txt',
    'tag_file': './data/weibo/pretrained_labels.txt',
    
    'loader_name': 'pre_loader',
    
    # "word_embedding_file": "./data/tencent/word_embedding.txt",
    # "word_vocab_file": "./data/tencent/tencent_vocab.txt",
    # "word_vocab_file_with_tag": "./data/tencent/tencent_vocab_with_tag.json",#这个文件没有

    "default_tag": "O",
    'batch_size': 16,
    'eval_batch_size': 64,
    'do_shuffle': True,
    'task_name': 'FN_Pretrained_5',
    "use_gpu": True,
    "debug": True,
    # "tag_rules": {
    #     "PER.NOM": "人的象征",
    #     "LOC.NAM": "地点",
    #     "PER.NAM": "人",
    #     "GPE.NAM": "政治实体",
    #     "ORG.NAM": "组织",
    #     "ORG.NOM": "组织的象征",
    #     "LOC.NOM": "地点的象征",
    #     "GPE.NOM": "政治实体的象征",
    #     "ORG": "组织",
    #     "LOC": "地点",
    #     "PER": "人",
    #     "Time": "时间",
    #     "Thing": "物品",
    #     "Metric": "测量单位",
    #     "Abstract": "抽象",
    #     "Physical": "身体部位",
    #     "Term": "学期",
    #     "company": "企业",
    #     "name": "名字",
    #     "game": "游戏",
    #     "movie": "电影",
    #     "position": "职位",
    #     "address": "地址",
    #     "government": "政府",
    #     "scene": "景点",
    #     "book": "书名"
    # }
}

pre_trainer = NERPreTrainer(**args)

for i in pre_trainer():
    a = i

# %%
# 1 文本实体、实体类型和标签都mask了
# 2 加上了负样例
# 3 文本实体不mask
# 4 文本都不mask 只mask标签
# 5 label没有-100
